# %%
# %%file HW1_Wind_Direction.py

import re
import json

from mrjob.job import MRJob

QUALITY_RE = re.compile(r"[01459]")

class WindDirection(MRJob):
    
    def mapper(self, _, line):
        val = line.strip()
        (direction, temp, q) = (val[60:63], val[87:92], val[63:64])
        if (direction != "999" and re.match(QUALITY_RE, q)):
            yield direction, temp

    def reducer(self, key, values):
        count = 0
        high = None
        low = None

        for v in values:
            temp = int(v)

            count += 1

            if high is None or temp > high:
                high = temp

            if low is None or temp < low:
                low = temp

        yield int(key), {"low": low, "high": high, "count": count}

if __name__ == '__main__':
    WindDirection.run()
# Out:
# Overwriting HW1_Wind_Direction.py

# %%
# !python HW1_Wind_Direction.py 1901 1902 | sort -n
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Creating temp directory /tmp/HW1_Wind_Direction.dxle.20260303.095532.165108
# Running step 1 of 1...
# job output is in /tmp/HW1_Wind_Direction.dxle.20260303.095532.165108/output
# Streaming final output from /tmp/HW1_Wind_Direction.dxle.20260303.095532.165108/output...
# Removing temp directory /tmp/HW1_Wind_Direction.dxle.20260303.095532.165108...
# 20	{"low": -272, "high": 317, "count": 582}
# 50	{"low": -322, "high": 306, "count": 1039}
# 70	{"low": -333, "high": 278, "count": 502}
# 90	{"low": -267, "high": 272, "count": 567}
# 110	{"low": -239, "high": 278, "count": 296}
# 140	{"low": -328, "high": 9999, "count": 1006}
# 160	{"low": -239, "high": 289, "count": 647}
# 180	{"low": -250, "high": 294, "count": 879}
# 200	{"low": -183, "high": 300, "count": 688}
# 230	{"low": -228, "high": 283, "count": 1488}
# 250	{"low": -222, "high": 311, "count": 604}
# ...
